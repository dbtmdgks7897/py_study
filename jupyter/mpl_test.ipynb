# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4],[1, 4, 9, 16], 'r')
plt.xlabel("Score")
plt.ylabel("Grade")
plt.show()

# %%
plt.bar([1,2,3,4], [1,4,9,16], color = 'skyblue')
# Out:
# <BarContainer object of 4 artists>
